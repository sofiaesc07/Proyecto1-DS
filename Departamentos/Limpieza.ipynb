# %%
#librerias a importar
import pandas as pd
import numpy as np

# %%
#Se importan los csv de cada uno de los departamentos
ALTA_VERAPAZ = pd.read_csv('ALTA_VERAPAZ.csv')
BAJA_VERAPAZ = pd.read_csv('BAJA_VERAPAZ.csv', encoding='latin-1')
CIUDAD_CAPITAL = pd.read_csv('CIUDAD_CAPITAL.csv')
GUATEMALA = pd.read_csv('GUATEMALA.csv', encoding='latin-1')
CHIMALTENANGO = pd.read_csv('CHIMALTENANGO.csv', encoding='latin-1')
CHIQUIMULA = pd.read_csv('CHIQUIMULA.csv', encoding='latin-1')
EL_PROGRESO = pd.read_csv('EL PROGRESO.csv', encoding='latin-1')
ESCUINTLA = pd.read_csv('ESCUINTLA.csv', encoding='latin-1')
HUEHUETENANGO = pd.read_csv('HUEHUETENANGO.csv', encoding='latin-1')
IZABAL = pd.read_csv('IZABAL.csv', encoding='latin-1')
JALAPA = pd.read_csv('JALAPA.csv', encoding='latin-1')
JUTIAPA = pd.read_csv('JUTIAPA.csv', encoding='latin-1')
PETEN = pd.read_csv('PETEN.csv', encoding='latin-1')
QUETZALTENANGO = pd.read_csv('QUETZALTENANGO.csv', encoding='latin-1')
QUICHE = pd.read_csv('QUICHE.csv', encoding='latin-1')
RETALHULEU = pd.read_csv('RETALHULEU.csv', encoding='latin-1')
SUSHITEPEQUEZ = pd.read_csv('SUCHITEPEQUEZ.csv', encoding='latin-1')
TOTONICAPAN = pd.read_csv('TOTONICAPAN.csv', encoding='latin-1')
ZACAPA = pd.read_csv('ZACAPA.csv', encoding='latin-1')

# %%
#Se concatenan todos los dataframes --- agregar los demas departamentos
df = pd.concat([ALTA_VERAPAZ, CIUDAD_CAPITAL, GUATEMALA, CHIMALTENANGO,CHIQUIMULA, EL_PROGRESO, ESCUINTLA, 
                BAJA_VERAPAZ, HUEHUETENANGO, IZABAL, JALAPA, JUTIAPA,PETEN,QUETZALTENANGO,QUICHE,RETALHULEU,
                SUSHITEPEQUEZ,TOTONICAPAN,ZACAPA ], axis=0, ignore_index=True)
df
# Out:
#                                 CODIGO DISTRITO  DEPARTAMENTO  MUNICIPIO  \
# 0                        16-01-0138-46   16-031  ALTA VERAPAZ      COBAN
# 1                        16-01-0139-46   16-031  ALTA VERAPAZ      COBAN
# 2                        16-01-0140-46   16-031  ALTA VERAPAZ      COBAN
# 3                        16-01-0141-46   16-005  ALTA VERAPAZ      COBAN
# 4                        16-01-0142-46   16-005  ALTA VERAPAZ      COBAN
# ...                                ...      ...           ...        ...
# 15981                    19-10-0013-46   19-015        ZACAPA      HUITE
# 15982                    19-10-1009-46   19-015        ZACAPA      HUITE
# 15983                    19-11-0018-46   19-020        ZACAPA  SAN JORGE
# 15984                              NaN      NaN           NaN        NaN
# 15985  95 Establecimientos encontrados      NaN           NaN        NaN
#
#                                          ESTABLECIMIENTO  \
# 0                                          COLEGIO COBAN
# 1                       COLEGIO PARTICULAR MIXTO VERAPAZ
# 2                                COLEGIO "LA INMACULADA"
# 3               ESCUELA NACIONAL DE CIENCIAS COMERCIALES
# 4      INSTITUTO NORMAL MIXTO DEL NORTE 'EMILIO ROSAL...
# ...                                                  ...
# 15981                            INSTITUTO DIVERSIFICADO
# 15982  INSTITUTO MIXTO DE EDUCACION DIVERSIFICADA POR...
# 15983  INSTITUTO MIXTO DE EDUCACIÓN DIVERSIFICADA POR...
# 15984                                                NaN
# 15985                                                NaN
#
#                                     DIRECCION    TELEFONO  \
# 0      KM.2 SALIDA A SAN JUAN CHAMELCO ZONA 8    77945104
# 1                KM 209.5 ENTRADA A LA CIUDAD    77367402
# 2                   7A. AVENIDA 11-109 ZONA 6    78232301
# 3                       2A CALLE 11-10 ZONA 2    79514215
# 4                         3A AVE 6-23 ZONA 11    79521468
# ...                                       ...         ...
# 15981                     BARRIO BUENOS AIRES  47097386.0
# 15982                         BARRIO EL CAMPO  55958103.0
# 15983                        BARRIO EL CENTRO  41447589.0
# 15984                                     NaN         NaN
# 15985                                     NaN         NaN
#
#                             SUPERVISOR                      DIRECTOR  \
# 0      MERCEDES JOSEFINA TORRES GALVEZ     JULIO CESAR VILLELA AMADO
# 1      MERCEDES JOSEFINA TORRES GALVEZ                           ---
# 2      MERCEDES JOSEFINA TORRES GALVEZ        VIRGINA SOLANO SERRANO
# 3                  RUDY ADOLFO TOT OCH                           NaN
# 4                  RUDY ADOLFO TOT OCH                           NaN
# ...                                ...                           ...
# 15981      YADIRA FERNANDA SOSA GUERRA  MARLON JOSUÉ ARCHILA LORENZO
# 15982      YADIRA FERNANDA SOSA GUERRA     ROBIDIO PORTILLO SALGUERO
# 15983                  ALBA LUZ MENDEZ     VICTOR HUGO GUERRA MONROY
# 15984                              NaN                           NaN
# 15985                              NaN                           NaN
#
#                NIVEL  ...    AREA   STATUS   MODALIDAD     JORNADA  \
# 0      DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    MATUTINA
# 1      DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    MATUTINA
# 2      DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    MATUTINA
# 3      DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    MATUTINA
# 4      DIVERSIFICADO  ...  URBANA  ABIERTA    BILINGUE  VESPERTINA
# ...              ...  ...     ...      ...         ...         ...
# 15981  DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    NOCTURNA
# 15982  DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE  VESPERTINA
# 15983  DIVERSIFICADO  ...  URBANA  ABIERTA  MONOLINGUE    MATUTINA
# 15984            NaN  ...     NaN      NaN         NaN         NaN
# 15985            NaN  ...     NaN      NaN         NaN         NaN
#
#                   PLAN DEPARTAMENTAL  \
# 0      DIARIO(REGULAR)  ALTA VERAPAZ
# 1      DIARIO(REGULAR)  ALTA VERAPAZ
# 2      DIARIO(REGULAR)  ALTA VERAPAZ
# 3      DIARIO(REGULAR)  ALTA VERAPAZ
# 4      DIARIO(REGULAR)  ALTA VERAPAZ
# ...                ...           ...
# 15981  DIARIO(REGULAR)        ZACAPA
# 15982  DIARIO(REGULAR)        ZACAPA
# 15983  DIARIO(REGULAR)        ZACAPA
# 15984              NaN           NaN
# 15985              NaN           NaN
#
#       CODIGO DISTRITO DEPARTAMENTO MUNICIPIO    ESTABLECIMIENTO       DIRECCION      TELEFONO SUPERVISOR        DIRECTOR         NIVEL       SECTOR    AREA        STATUS     MODALIDAD    JORNADA        PLAN       DEPARTA  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
# 15984                                                NaN
# 15985                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO        MUNICIPIO      ESTABLECIMIENTO       DIRECCION       TELEFONO SUPERVISOR      DIRECTOR      NIVEL        SECTOR      AREA        STATUS     MODALIDAD   JORNADA        PLAN  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
# 15984                                                NaN
# 15985                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO       MUNICIPIO    ESTABLECIMIENTO       DIRECCION          TELEFONO SUPERVISOR         DIRECTOR        NIVEL        SECTOR    AREA        STATUS     MODALIDAD    JORNADA        PLAN  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
# 15984                                                NaN
# 15985                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO MUNICIPIO      ESTABLECIMIENTO         DIRECCION          TELEFONO SUPERVISOR      DIRECTOR      NIVEL        SECTOR       AREA        STATUS    MODALIDAD   JORNADA        PLAN       DE
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
# 15984                                                NaN
# 15985                                                NaN
#
# [15986 rows x 21 columns]

# %%
#Listamos los nombres de las columnas
list(df.keys())

#Borramos filas duplicadas
df=df.drop_duplicates()

# %%
#Observamos la cantidad de na de cada variable
print('CODIGO: ', df['CODIGO'].isna().sum())
print('DISTRITO: ', df['DISTRITO'].isna().sum())
print('DEPARTAMENTO: ', df['DEPARTAMENTO'].isna().sum())
print('MUNICIPIO: ', df['MUNICIPIO'].isna().sum())
print('ESTABLECIMIENTO: ', df['ESTABLECIMIENTO'].isna().sum())
print('DIRECCION: ', df['DIRECCION'].isna().sum())
print('TELEFONO: ', df['TELEFONO'].isna().sum())
print('SUPERVISOR: ', df['SUPERVISOR'].isna().sum())
print('DIRECTOR: ', df['DIRECTOR'].isna().sum())
print('NIVEL: ', df['NIVEL'].isna().sum())
print('SECTOR: ', df['SECTOR'].isna().sum())
print('AREA: ', df['AREA'].isna().sum())
print('STATUS: ', df['STATUS'].isna().sum())
print('MODALIDAD: ', df['MODALIDAD'].isna().sum())
print('JORNADA: ', df['JORNADA'].isna().sum())
print('PLAN: ', df['PLAN'].isna().sum())
print('DEPARTAMENTAL: ', df['DEPARTAMENTAL'].isna().sum())
# Out:
# CODIGO:  6981
# DISTRITO:  7159
# DEPARTAMENTO:  6996
# MUNICIPIO:  6996
# ESTABLECIMIENTO:  6996
# DIRECCION:  7027
# TELEFONO:  7395
# SUPERVISOR:  7159
# DIRECTOR:  8046
# NIVEL:  6996
# SECTOR:  6996
# AREA:  6996
# STATUS:  6996
# MODALIDAD:  6996
# JORNADA:  6996
# PLAN:  6996
# DEPARTAMENTAL:  6996

# %%
#Botamos todas las filas con valores nulos en el código o establecimiento ya que estas deberían de ser unicas
df=df.dropna(subset = ['CODIGO', 'ESTABLECIMIENTO'])
df
# Out:
#               CODIGO DISTRITO  DEPARTAMENTO  MUNICIPIO  \
# 0      16-01-0138-46   16-031  ALTA VERAPAZ      COBAN
# 1      16-01-0139-46   16-031  ALTA VERAPAZ      COBAN
# 2      16-01-0140-46   16-031  ALTA VERAPAZ      COBAN
# 3      16-01-0141-46   16-005  ALTA VERAPAZ      COBAN
# 4      16-01-0142-46   16-005  ALTA VERAPAZ      COBAN
# ...              ...      ...           ...        ...
# 15979  19-09-0040-46   19-021        ZACAPA   LA UNION
# 15980  19-09-0048-46   19-021        ZACAPA   LA UNION
# 15981  19-10-0013-46   19-015        ZACAPA      HUITE
# 15982  19-10-1009-46   19-015        ZACAPA      HUITE
# 15983  19-11-0018-46   19-020        ZACAPA  SAN JORGE
#
#                                          ESTABLECIMIENTO  \
# 0                                          COLEGIO COBAN
# 1                       COLEGIO PARTICULAR MIXTO VERAPAZ
# 2                                COLEGIO "LA INMACULADA"
# 3               ESCUELA NACIONAL DE CIENCIAS COMERCIALES
# 4      INSTITUTO NORMAL MIXTO DEL NORTE 'EMILIO ROSAL...
# ...                                                  ...
# 15979                     LICEO PARTICULAR MIXTO "JIREH"
# 15980                    LICEO PARTICULAR MIXTO " JIREH"
# 15981                            INSTITUTO DIVERSIFICADO
# 15982  INSTITUTO MIXTO DE EDUCACION DIVERSIFICADA POR...
# 15983  INSTITUTO MIXTO DE EDUCACIÓN DIVERSIFICADA POR...
#
#                                     DIRECCION    TELEFONO  \
# 0      KM.2 SALIDA A SAN JUAN CHAMELCO ZONA 8    77945104
# 1                KM 209.5 ENTRADA A LA CIUDAD    77367402
# 2                   7A. AVENIDA 11-109 ZONA 6    78232301
# 3                       2A CALLE 11-10 ZONA 2    79514215
# 4                         3A AVE 6-23 ZONA 11    79521468
# ...                                       ...         ...
# 15979                            BARRIO NUEVO  79418369.0
# 15980                            BARRIO NUEVO  79418369.0
# 15981                     BARRIO BUENOS AIRES  47097386.0
# 15982                         BARRIO EL CAMPO  55958103.0
# 15983                        BARRIO EL CENTRO  41447589.0
#
#                                 SUPERVISOR  \
# 0          MERCEDES JOSEFINA TORRES GALVEZ
# 1          MERCEDES JOSEFINA TORRES GALVEZ
# 2          MERCEDES JOSEFINA TORRES GALVEZ
# 3                      RUDY ADOLFO TOT OCH
# 4                      RUDY ADOLFO TOT OCH
# ...                                    ...
# 15979  BERTA ALICIA LEIVA CORDON DE GARCIA
# 15980  BERTA ALICIA LEIVA CORDON DE GARCIA
# 15981          YADIRA FERNANDA SOSA GUERRA
# 15982          YADIRA FERNANDA SOSA GUERRA
# 15983                      ALBA LUZ MENDEZ
#
#                                   DIRECTOR          NIVEL  ...    AREA  \
# 0                JULIO CESAR VILLELA AMADO  DIVERSIFICADO  ...  URBANA
# 1                                      ---  DIVERSIFICADO  ...  URBANA
# 2                   VIRGINA SOLANO SERRANO  DIVERSIFICADO  ...  URBANA
# 3                                      NaN  DIVERSIFICADO  ...  URBANA
# 4                                      NaN  DIVERSIFICADO  ...  URBANA
# ...                                    ...            ...  ...     ...
# 15979  ANA MARÍA CUELLAR GUERRA DE RAMÍREZ  DIVERSIFICADO  ...  URBANA
# 15980  ANA MARÍA CUELLAR GUERRA DE RAMÍREZ  DIVERSIFICADO  ...  URBANA
# 15981         MARLON JOSUÉ ARCHILA LORENZO  DIVERSIFICADO  ...  URBANA
# 15982            ROBIDIO PORTILLO SALGUERO  DIVERSIFICADO  ...  URBANA
# 15983            VICTOR HUGO GUERRA MONROY  DIVERSIFICADO  ...  URBANA
#
#         STATUS   MODALIDAD      JORNADA                                 PLAN  \
# 0      ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
# 1      ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
# 2      ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
# 3      ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
# 4      ABIERTA    BILINGUE   VESPERTINA                      DIARIO(REGULAR)
# ...        ...         ...          ...                                  ...
# 15979  ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
# 15980  ABIERTA  MONOLINGUE  SIN JORNADA  SEMIPRESENCIAL (UN DÍA A LA SEMANA)
# 15981  ABIERTA  MONOLINGUE     NOCTURNA                      DIARIO(REGULAR)
# 15982  ABIERTA  MONOLINGUE   VESPERTINA                      DIARIO(REGULAR)
# 15983  ABIERTA  MONOLINGUE     MATUTINA                      DIARIO(REGULAR)
#
#       DEPARTAMENTAL  \
# 0      ALTA VERAPAZ
# 1      ALTA VERAPAZ
# 2      ALTA VERAPAZ
# 3      ALTA VERAPAZ
# 4      ALTA VERAPAZ
# ...             ...
# 15979        ZACAPA
# 15980        ZACAPA
# 15981        ZACAPA
# 15982        ZACAPA
# 15983        ZACAPA
#
#       CODIGO DISTRITO DEPARTAMENTO MUNICIPIO    ESTABLECIMIENTO       DIRECCION      TELEFONO SUPERVISOR        DIRECTOR         NIVEL       SECTOR    AREA        STATUS     MODALIDAD    JORNADA        PLAN       DEPARTA  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15979                                                NaN
# 15980                                                NaN
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO        MUNICIPIO      ESTABLECIMIENTO       DIRECCION       TELEFONO SUPERVISOR      DIRECTOR      NIVEL        SECTOR      AREA        STATUS     MODALIDAD   JORNADA        PLAN  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15979                                                NaN
# 15980                                                NaN
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO       MUNICIPIO    ESTABLECIMIENTO       DIRECCION          TELEFONO SUPERVISOR         DIRECTOR        NIVEL        SECTOR    AREA        STATUS     MODALIDAD    JORNADA        PLAN  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15979                                                NaN
# 15980                                                NaN
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
#
#       CODIGO DISTRITO DEPARTAMENTO MUNICIPIO      ESTABLECIMIENTO         DIRECCION          TELEFONO SUPERVISOR      DIRECTOR      NIVEL        SECTOR       AREA        STATUS    MODALIDAD   JORNADA        PLAN       DE
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15979                                                NaN
# 15980                                                NaN
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
#
# [6566 rows x 21 columns]

# %%
#Contamos las repeticiones de establecimientos
df.ESTABLECIMIENTO.value_counts()
# Out:
# INSTITUTO NACIONAL DE EDUCACION DIVERSIFICADA             185
# INSTITUTO NACIONAL DE EDUCACIÓN DIVERSIFICADA              61
# INSTITUTO DIVERSIFICADO POR COOPERATIVA                    14
# INSTITUTO GUATEMALTECO DE EDUCACION RADIOFONICA (IGER)     14
# ESCUELA NORMAL DE EDUCACION FISICA                         13
#                                                          ...
# COLEGIO EXPERIMENTAL CRISTIANO VERBO NO. 4                  1
# COLEGIO CATOLICO MIXTO MARIA AUXILIO DE LOS CRISTIANOS      1
# COLEGIO MIXTO 'FORJADOR DE JUVENTUDES'                      1
# LICEO MIXTO BRIGADA JUVENIL                                 1
# INSTITUTO DIVERSIFICADO                                     1
# Name: ESTABLECIMIENTO, Length: 3802, dtype: int64

# %%
#Removemos acentos
cols = df.select_dtypes(include=[object]).columns
df[cols] = df[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
df.ESTABLECIMIENTO.value_counts()
# Out:
# INSTITUTO NACIONAL DE EDUCACION DIVERSIFICADA                     247
# ASOCIACION DE MAESTROS DE EDUCACION RURAL DE GUATEMALA -AMERG-     17
# INSTITUTO DE COMPUTACION INFORMATICA                               15
# INSTITUTO DIVERSIFICADO POR COOPERATIVA                            14
# INSTITUTO GUATEMALTECO DE EDUCACION RADIOFONICA (IGER)             14
#                                                                  ...
# COLEGIO JUAN GERARDI                                                1
# COLEGIO INDOAMERICANO                                               1
# COLEGIO SAN LUIS DE FRANCIA                                         1
# LICEO MIXTO BILINGUE MILENIO AMERICANO                              1
# INSTITUTO DIVERSIFICADO                                             1
# Name: ESTABLECIMIENTO, Length: 3526, dtype: int64

# %% [markdown]
# #### Variable Departamento
#
# Ciudad Capital tenian sus datos distribuidos de una manera distinta pues la variables DEPARTAMENTO guarda el municipio del establecimiento y la variable MUNICIPIO guarda la zona de la capital en la que recide, así que se crea una variable para reordenar estos datos y volver a la ciudad capital parte de guatemala

# %%
#creamos la variable zona para la ciudad capital
df = df.assign(ZONA = lambda x: np.where(x.DEPARTAMENTO == "CIUDAD CAPITAL", x.MUNICIPIO, None))
#volvemos el departamento un municipio 
df = df.assign(MUNICIPIO = lambda x: np.where(x.DEPARTAMENTO == "CIUDAD CAPITAL", x.DEPARTAMENTO, x.MUNICIPIO))
#unimos ciudad capital a guatemala
df = df.assign(DEPARTAMENTO = lambda x: np.where(x.DEPARTAMENTO == "CIUDAD CAPITAL", "GUATEMALA", x.DEPARTAMENTO))

# %% [markdown]
# #### Variable dirección
#
# Esta variable tiene diferentes tipos de formatos, decidimos validar direcciones claramente erroneas, constituidas por un par decaracteres invalidos, como "-", "--", "---", ".", "". y las definimos como NONE.

# %%
setFaltasDireccion = ['-', '--', '---', '.', ' ', '  ']
df.DIRECCION = df.DIRECCION.replace(setFaltasDireccion, None)

# %% [markdown]
# #### Variable Telefono
#
# A muchos numeros telefonicos les faltan numeros, fueron guardados con decimales o inculo algunos establecimientos cuentan con más de un numero telefonico

# %%
#i una entrada posee 8 caracteres o más, botamos la cola del dato y nos quedamos con los primeros 8 caracteres. 
# Si es menor a 8 o posee caracteres es desechado

df['TELEFONO'] = df['TELEFONO'].apply(lambda x: str(x))
df['TELEFONO'] = df['TELEFONO'].apply(lambda x: x[0:8] if len(x) >= 8  else None)

# %% [markdown]
# #### Variable Director
#
# En algunos establecimientos no aparece quien es el directos y aparecen puntos o caracteres diferentes así que nos cambiamos por NaN

# %%
#Contamos las repeticiones de directores
print(df.DIRECTOR.value_counts())

#Convertimos en NaN todos 
df['DIRECTOR']=df['DIRECTOR'].replace('.',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('..',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('...',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('--',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('---',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('----',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-----',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('--------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('---------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('----------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-----------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('--------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('---------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('----------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-----------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('-------------------',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('0',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('X',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace(' ',np.NaN)
df['DIRECTOR']=df['DIRECTOR'].replace('SIN DATO',np.NaN)

df.DIRECTOR.value_counts()
# Out:
# ---                               145
# --                                 57
# ----                               35
# .                                  29
# -----                              26
#                                  ...
# CARLOS ENRIQUE CARDONA MARIN        1
# RUBBY ELIZABETH TURCIOS OSORIO      1
# AURA REYNOSA LOPEZ                  1
# CINDY CAROLINA LARA ALAY            1
# ROBIDIO PORTILLO SALGUERO           1
# Name: DIRECTOR, Length: 3160, dtype: int64
# JORGE GRANADOS GUZMAN                13
# IRIS MARICLO MORALES LUNA            12
# MARIA DOLORES PEREZ TUCHAN           11
# CRISTIAN ALEXANDER PEREZ GONZALEZ     9
# EVA JUDITH HERNANDEZ MARQUEZ          9
#                                      ..
# JENNE DINA BOSQUE MERRON              1
# EVELYN PATRICIA CUMES NUELA           1
# FERNANDO AUGUSTO SIGUANTAY FLORES     1
# ESGAR AMILCAR LUCH CANEL              1
# ROBIDIO PORTILLO SALGUERO             1
# Name: DIRECTOR, Length: 3138, dtype: int64

# %%
##creamos un csv con los datos limpios
df.to_csv('DatosLimpios.csv')
